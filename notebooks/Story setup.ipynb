# %% [markdown]
# ## Homework 2
# Niels: Introduction, motivating the story, finding articles, use nice plots to motivate the story.
#
# **I strongly advise you get an extension that hides the code cells while we are still writing in notebooks**

# %% [markdown]
# # Overfishing in culture

# %%
# Imports
import pandas as pd
import plotly.express as px
import seaborn as sns
from matplotlib import pyplot as plt
from operator import truediv

# %%
# Notes on introduction:
# Should be chaged somewhat once we know exactly which aspects we will focus on
# Important to clarify we want other cultures to learn from the better ones without destroying their own culture

# %% [markdown]
# ### Introduction
# Culture has been called "the way of life for an entire society." As such, it includes codes of manners, dress, language, religion, rituals, art and the list goes on and on. In this article we will be discussing the current standing of fish and fishing in human cultures. More specifically how the roles of their economic importance in the fishing industry and fish farming is related to other cultural aspects such as *recreational fishing, fish cuisine, folklore, mythology, religion, art, literature, and film.*
#
# The reason we do this is simple. Overfishing has become a mayor global issue. It is one of the greatest ecological, manmade threats now wreaking havoc on our ecosystems. There are many causes and consequences to this issue, but as with almost all manmade threads not everyone is responsable equally. Some cultures are more at fault for causing the issue, where others are suffering more from the consequences.
#
# We want to know which countries, if any, have the healthiest and least healthy fishing industries and what cultural aspects have allowed for this development. Hopefully answering these questions will allow other cultures to tackle their contribution to the problem of overfishing without having to compromise their own culture.

# %% [markdown]
# ### The problem
# What we are starting to see is that the very skills that have allowed us to survive and thrive over the last thousands of years are now leading us to our destruction. This can clearly be seen in the fishing industry.
#
# "An average person is now consuming twice (about 20kg per year) as much food than they did 50 years ago. Additionally, the global population has nearly quadrupled since the end of the 1960s. In other words, we are not only eating more, but we’ve also created four times more mouths to feed. As a consequence, the health of the seas, its inhabitants, and those whose livelihood depends on it, are suddenly finding themselves struggling."[[1]](https://www.ecomagazine.com/news/policy/overfishing-is-a-huge-problem-here-s-what-you-need-to-know#:~:text=One%20of%20the%20greatest%20ecological,the%20end%20of%20the%201960s.)

# %%
data = pd.read_csv("fish-and-seafood-consumption-per-capita.csv")

# %%
data_grouped = data.groupby(["Year"]).mean()

# %%
data_grouped.rename(columns={"Fish, Seafood- Food supply quantity (kg/capita/yr) (FAO, 2020)": "Mean global seafood consumption"}, inplace=True)

# %%
plt.rcParams['figure.figsize'] = [10, 5]

fig = plt.figure( )

data_grouped.plot(kind="line")
plt.xlabel( "Year" )
plt.ylabel( "kg/capita" )
plt.title( "" , fontdict = {'fontsize': 14} )

plt.show();

# %% [markdown]
# Every day fisherman the world over set out to see and catch an immeasurable amount of fish to keep up with this growing demand. What the term overfishing essentially means is that we are catching more fish then can be naturally replenished. The figure below shows how overfishing has increased over the last decades. In the figure an overexploitation level of 40% means that to be farming fish optimally we should be fishing 40% less, since if we do this we keep more fish in the sea and therefore they can reproduce faster. 60 fish can make 10 babies faster then 40 fish. **Not sure how to explain this section properly to a general audience**

# %%
sustainable = pd.read_csv('../github/socialdata-overfishing/data/fish-stocks-within-sustainable-levels.csv')

# %%
sustainable_world = sustainable[sustainable["Entity"]=="World"]

# %%
sus = sustainable_world['Share of fish stocks within biologically sustainable levels (FAO, 2020)'].tolist()
over = sustainable_world['Share of fish stocks that are overexploited'].tolist()
#sus = sus/sus
sus_map = list(map(truediv, sus, sus))
#over = over/sus
over_map = list(map(truediv, over, sus))

index = sustainable_world['Year']
df = pd.DataFrame({#'sustainable': sus_map,
                   'overexploited': over_map}, index=index)
ax = df.plot.barh(figsize=(10,7))
ax.set_xlabel('%')
ax.set_title('Share of world fish stocks within sustainable and overexploited levels');

# %% [markdown]
# ### Consequences

# %% [markdown]
# One of the more talked about consecueses of our global fishing habits in the main stream media is the extincion of many fish species. **interesting papers** [[one]](https://conbio.onlinelibrary.wiley.com/doi/full/10.1111/j.1755-263X.2011.00206.x) [[two]](https://conbio.onlinelibrary.wiley.com/doi/full/10.1111/j.1755-263X.2011.00206.x) This alone can have irreversible reprecussions, however is only one of many consequences that are creating chaos in a perfectly balanced ecosystem. Others include: (this is copied and needs work)
#
# - Predators, particularly large ones like sharks, dolphins, whales, and tuna, who are essential to maintaining the balanced ecosystem, are often innocent bystanders, caught in a trawler’s nets.
#
# - The decrease in algea eating fish, causes an increase in the amount of algea who's acidity can negatively impact fish population, plankton, and reefs.
#
# - Objects used for fishing illegaly being dumped into the ocean, creating traps for all kinds of marine animals.
#
# - In many cases, fishermen disregard maritime law and venture without permission into foreign waters, which can be seen as a sign of agression.
#
# - Rural, and in many cases isolated communities, rely on fishing not for income but for dietary purposes, with fish being their main source of protein. With the depletion of the fish population, they find their very way of life threatened.
#
# Most of these issues are hard to get people to care about, since they don't immediately effect us. So let's convey a problem that hits a little closer to home, our wallets.
#
# Many coastal nations rely on the fishing industry for a huge portion of their gross domestic product, often on the sale taxes it generates. And overfishing while creating an immediate boost in profits destroy the whole industry in a matter of years. Since it reduces the fish population, which means there are less fish left to catch each year. This also ends up increasing the price of fish due to a declining supply.

# %% [markdown]
# ### Causes

# %% [markdown]
# There are dozens of reason for overfishing. And it is essential to note that each region has a has their own political and economical reasons that are creating the crisis. We simply can’t place Pakistan, Ireland, and China into the same boat. Each country and government has contributed their own unique problems. These circumstances are what we want to look at later on, but first lets mention a feww usiversal causes:
#
# - There is a hugh challenge in regulating fishing vessels at the ports. The amount of vassels is just to large and most governments lack the resources for this work.
#
# - There is a lack of oversight when it comes to how much individual vassels are fishing, allowing them to overfish at will.
#
# - There are little to no regulations on international waters.
#
# - It is hard for countries to know the current fish populations and therefore the optimal fishing quotas.
#
# - Many public officials are either ignorant to fishing regulations and problems, which allows many fishermen to get around fishing laws.
#
# - Small vassels are able to fish and unload without being detected.
#
# - There is a rise in mobile processing plant, big tankers that are capable of canning that days catch instantly, which allows companies to import canned food instead of fresh fish. *not sure why this is an issue
#
# - Goverments have creating an enviroment where we have an estimated three times more fleets then necessairy. This is due to high subsidies for fisherman.
#
# - Only 1.5% of the world’s oceans are protected waters, leaving the rest fair game for fisherman.

# %% [markdown]
# ### Introduction to our cases

# %% [markdown]
# One promising solution to overfishing in the growing fish farming industry. It has some mayor benefits with regard to regular fishing, namely that it's much more regulated and doesn't impact a larger ecosystem. However it has plenty of downsides as well, which means it will never be able to substitude fully for fishing. It is important that we create a healthy fishing enviroment worldwide, so let's start lokking at how we might do that.
#
# As mentioned before we will comparing the healthiest and least healthy fishing industries worldwide in order to analyze how the local culture and regulations have shaped it.
#
# To determine our use cases we will analyze which countries ...
#
# EXPLAIN CHOICE OF COUNTRIES
#
# WHAT EXACTLY WILL WE BE LOOKING AT IN EACH CASE AND WHY

# %%
What is it

cause

effect

plots...

# %% [markdown]
# ### Country 1

# %% [markdown]
# ### Country 2

# %% [markdown]
# ### Country 3

# %% [markdown]
# ### Conclusion
